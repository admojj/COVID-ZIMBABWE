# %%
import pandas as pd

# %%
# read the mobility data csv file
zimmobdf = pd.read_csv('Data/Zimbabwe/Global_Mobility_Report.csv')
zimmobdf
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        country_region_code        country_region       sub_region_1  \
# 0                       AE  United Arab Emirates                NaN
# 1                       AE  United Arab Emirates                NaN
# 2                       AE  United Arab Emirates                NaN
# 3                       AE  United Arab Emirates                NaN
# 4                       AE  United Arab Emirates                NaN
# ...                    ...                   ...                ...
# 547917                  ZW              Zimbabwe  Midlands Province
# 547918                  ZW              Zimbabwe  Midlands Province
# 547919                  ZW              Zimbabwe  Midlands Province
# ...

# %%
#rename the column headings
zimmobdf.columns = ['Country Code', 'CNTRY_NAME', 'region1', 'region2', 'iso3', 'FIPS', 'date', 'retail_and_recreation', 'grocery_and_pharmacy', 'parks', 'transit_stations', 'workplaces', 'residential']
zimmobdf
# Out:
#        Country Code            CNTRY_NAME            region1 region2   iso3  \
# 0                AE  United Arab Emirates                NaN     NaN    NaN
# 1                AE  United Arab Emirates                NaN     NaN    NaN
# 2                AE  United Arab Emirates                NaN     NaN    NaN
# 3                AE  United Arab Emirates                NaN     NaN    NaN
# 4                AE  United Arab Emirates                NaN     NaN    NaN
# ...             ...                   ...                ...     ...    ...
# 547917           ZW              Zimbabwe  Midlands Province     NaN  ZW-MI
# 547918           ZW              Zimbabwe  Midlands Province     NaN  ZW-MI
# 547919           ZW              Zimbabwe  Midlands Province     NaN  ZW-MI
# 547920           ZW              Zimbabwe  Midlands Province     NaN  ZW-MI
# 547921           ZW              Zimbabwe  Midlands Province     NaN  ZW-MI
#
# ...

# %%
#drop columns region1  and region2 
zimmobdf.drop(['region2', 'iso3', 'FIPS'],axis=1, inplace=True)
zimmobdf
# Out:
#        Country Code            CNTRY_NAME            region1        date  \
# 0                AE  United Arab Emirates                NaN  2020-02-15
# 1                AE  United Arab Emirates                NaN  2020-02-16
# 2                AE  United Arab Emirates                NaN  2020-02-17
# 3                AE  United Arab Emirates                NaN  2020-02-18
# 4                AE  United Arab Emirates                NaN  2020-02-19
# ...             ...                   ...                ...         ...
# 547917           ZW              Zimbabwe  Midlands Province  2020-06-10
# 547918           ZW              Zimbabwe  Midlands Province  2020-06-11
# 547919           ZW              Zimbabwe  Midlands Province  2020-06-12
# 547920           ZW              Zimbabwe  Midlands Province  2020-06-13
# 547921           ZW              Zimbabwe  Midlands Province  2020-06-14
#
#         retail_and_recreation  grocery_and_pharmacy  parks  transit_stations  \
# ...

# %%
# Select df.desired column row == Zimbabwe
zimmobility = zimmobdf[(zimmobdf.CNTRY_NAME == "Zimbabwe")]
zimmobility
# Out:
#        Country Code CNTRY_NAME            region1        date  \
# 546754           ZW   Zimbabwe                NaN  2020-02-15
# 546755           ZW   Zimbabwe                NaN  2020-02-16
# 546756           ZW   Zimbabwe                NaN  2020-02-17
# 546757           ZW   Zimbabwe                NaN  2020-02-18
# 546758           ZW   Zimbabwe                NaN  2020-02-19
# ...             ...        ...                ...         ...
# 547917           ZW   Zimbabwe  Midlands Province  2020-06-10
# 547918           ZW   Zimbabwe  Midlands Province  2020-06-11
# 547919           ZW   Zimbabwe  Midlands Province  2020-06-12
# 547920           ZW   Zimbabwe  Midlands Province  2020-06-13
# 547921           ZW   Zimbabwe  Midlands Province  2020-06-14
#
#         retail_and_recreation  grocery_and_pharmacy  parks  transit_stations  \
# 546754                   -4.0                   0.0   -1.0             -11.0
# ...

# %%
# Select df.desired column row == Zimbabwe
zimmobility2 = zimmobdf[(zimmobdf.region1 == "Harare Province")]
zimmobility2
# Out:
#        Country Code CNTRY_NAME          region1        date  \
# 546996           ZW   Zimbabwe  Harare Province  2020-02-15
# 546997           ZW   Zimbabwe  Harare Province  2020-02-16
# 546998           ZW   Zimbabwe  Harare Province  2020-02-17
# 546999           ZW   Zimbabwe  Harare Province  2020-02-18
# 547000           ZW   Zimbabwe  Harare Province  2020-02-19
# ...             ...        ...              ...         ...
# 547112           ZW   Zimbabwe  Harare Province  2020-06-10
# 547113           ZW   Zimbabwe  Harare Province  2020-06-11
# 547114           ZW   Zimbabwe  Harare Province  2020-06-12
# 547115           ZW   Zimbabwe  Harare Province  2020-06-13
# 547116           ZW   Zimbabwe  Harare Province  2020-06-14
#
#         retail_and_recreation  grocery_and_pharmacy  parks  transit_stations  \
# 546996                   -5.0                  -3.0    0.0             -12.0
# 546997                  -12.0                  -4.0  -17.0             -14.0
# ...

# %%
# Using plotly.express
import plotly.express as px

import pandas as pd


fig = px.line(zimmobility2, x='date', y='retail_and_recreation', range_x=['2020-02-15','2020-06-20'], title='Harare retail and recreation mobility trends',)

fig.show()
# Out:
# <div>
#
#
#             <div id="0c6c73d9-d601-4b74-90df-4200835304a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0c6c73d9-d601-4b74-90df-4200835304a9")) {
#                     Plotly.newPlot(
#                         '0c6c73d9-d601-4b74-90df-4200835304a9',
# ...

# %%
# Using plotly.express
import plotly.express as px

import pandas as pd


fig = px.line(zimmobility2, x='date', y='workplaces', range_x=['2020-02-15','2020-06-20'], title='Harare Workplaces',)

fig.show()
# Out:
# <div>
#
#
#             <div id="5ae0259a-1bf3-4de7-9b52-c2c52bfbaef0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5ae0259a-1bf3-4de7-9b52-c2c52bfbaef0")) {
#                     Plotly.newPlot(
#                         '5ae0259a-1bf3-4de7-9b52-c2c52bfbaef0',
# ...

# %%
# Using plotly.express
import plotly.express as px

import pandas as pd


fig = px.line(zimmobility2, x='date', y='residential', range_x=['2020-02-15','2020-06-20'], title='Harare residential',)

fig.show()
# Out:
# <div>
#
#
#             <div id="2793a0dc-73d2-4b74-8bcb-ae8e70e91398" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2793a0dc-73d2-4b74-8bcb-ae8e70e91398")) {
#                     Plotly.newPlot(
#                         '2793a0dc-73d2-4b74-8bcb-ae8e70e91398',
# ...

# %%
import plotly.graph_objects as go
import datetime
import numpy as np
np.random.seed(1)

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
min_date=zimmobility.min()
max_date=zimmobility.max()

# %%
min_date
# Out:
# Country Code                     ZW
# CNTRY_NAME                 Zimbabwe
# date                     2020-02-15
# retail_and_recreation           -81
# grocery_and_pharmacy            -73
# parks                           -80
# transit_stations                -91
# workplaces                      -85
# residential                      -4
# dtype: object

# %%
fig = go.Figure(data=go.Heatmap(
        z=zimmobility['workplaces'],
        x=zimmobility['date'],
        y=zimmobility['region1'],       
        colorscale='plasma',
        colorbar=dict(thickness=20,lenmode='fraction',len=0.8,
                      tickcolor='black',tickfont=dict(size=10),y=0.8,
                     title='mobility workplaces')
))

fig.update_layout(
    #title='Heat Map, Mobility in Zimbabwe, '+min_date+' to '+max_date, 
    titlefont=dict(size=14),
    yaxis_nticks=len(zimmobility['region1'].unique()),
    xaxis_nticks=len(zimmobility['date'].unique()),
    width=1000,
    height=700,
    yaxis=dict(title_text="Province", titlefont=dict(size=12),tickfont=dict(size=9)),
    xaxis=dict(title_text="Report Date",titlefont=dict(size=12),tickfont=dict(size=9)),
    margin=dict(l=50, r=50, b=100, t=100,pad=4)
)

fig.show()
# Out:
# <div>
#
#
#             <div id="2a45f6e5-246a-434c-b2ca-573c58c293c8" class="plotly-graph-div" style="height:700px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2a45f6e5-246a-434c-b2ca-573c58c293c8")) {
#                     Plotly.newPlot(
#                         '2a45f6e5-246a-434c-b2ca-573c58c293c8',
# ...

# %%
fig = go.Figure(data=go.Heatmap(
        z=zimmobility['retail_and_recreation'],
        x=zimmobility['date'],
        y=zimmobility['region1'],       
        colorscale='plasma',
        colorbar=dict(thickness=20,lenmode='fraction',len=0.8,
                      tickcolor='black',tickfont=dict(size=10),y=0.8,
                     title='mobility retail&recreation')
))

fig.update_layout(
    #title='Heat Map, Mobility in Zimbabwe, '+min_date+' to '+max_date, 
    titlefont=dict(size=14),
    yaxis_nticks=len(zimmobility['region1'].unique()),
    xaxis_nticks=len(zimmobility['date'].unique()),
    width=1100,
    height=700,
    yaxis=dict(title_text="Province", titlefont=dict(size=12),tickfont=dict(size=9)),
    xaxis=dict(title_text="Report Date",titlefont=dict(size=12),tickfont=dict(size=9)),
    margin=dict(l=50, r=50, b=100, t=100,pad=4)
)

fig.show()
# Out:
# <div>
#
#
#             <div id="bf555598-dbab-44c5-b594-5828415323f3" class="plotly-graph-div" style="height:700px; width:1100px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bf555598-dbab-44c5-b594-5828415323f3")) {
#                     Plotly.newPlot(
#                         'bf555598-dbab-44c5-b594-5828415323f3',
# ...

# %% [markdown]
# # Tracking Mobility Using Facebook data for good
# https://data.humdata.org/dataset/c3429f0e-651b-4788-bb2f-4adbf222c90e/resource/31ca909c-10d9-458a-8720-88b54b3e3627/download/movement-range-data-2020-06-13.zip

# %%
import pandas as pd
zimmobdf4 = pd.read_csv('Data/Zimbabwe/Zimbabwefb.csv')
zimmobdf4
# Out:
#        Column1 Column2 Column3    Column4     Column5  Column6  Column7  \
# 0     1/3/2020     ZWE    GADM  ZWE.1.1_1    Bulawayo -0.13823  0.18672
# 1     2/3/2020     ZWE    GADM  ZWE.1.1_1    Bulawayo  0.03095  0.10094
# 2     3/3/2020     ZWE    GADM  ZWE.1.1_1    Bulawayo -0.03279  0.12880
# 3     4/3/2020     ZWE    GADM  ZWE.1.1_1    Bulawayo -0.06359  0.13719
# 4     5/3/2020     ZWE    GADM  ZWE.1.1_1    Bulawayo -0.01353  0.13230
# ..         ...     ...     ...        ...         ...      ...      ...
# 813   9/6/2020     ZWE    GADM  ZWE.9.1_1  Beitbridge -0.02396  0.06795
# 814  10/6/2020     ZWE    GADM  ZWE.9.1_1  Beitbridge -0.02233  0.09101
# 815  11/6/2020     ZWE    GADM  ZWE.9.1_1  Beitbridge  0.00065  0.10190
# 816  12/6/2020     ZWE    GADM  ZWE.9.1_1  Beitbridge -0.05717  0.10207
# 817  13/6/2020     ZWE    GADM  ZWE.9.1_1  Beitbridge -0.18070  0.08213
#
#            Column8      Column9
# 0    full_february  DAY_OF_WEEK
# 1    full_february  DAY_OF_WEEK
# ...

# %%
zimmobdf4.columns = ['Date', 'Country', 'Source', 'Source_Code', 'City', '%Mobility Change', '%Staying Put', 'Baseline', 'Measure']

# %%
import plotly.express as px

import pandas as pd


fig = px.line(zimmobdf4, x='Date', y='%Staying Put', color = 'City', range_x=['2020-02-15','2020-05-29'], title='Residents Staying at Home',)

fig.show()
# Out:
# <div>
#
#
#             <div id="334f9124-a21e-4ea3-a4ce-081e84a71594" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("334f9124-a21e-4ea3-a4ce-081e84a71594")) {
#                     Plotly.newPlot(
#                         '334f9124-a21e-4ea3-a4ce-081e84a71594',
# ...

# %%
import plotly.express as px

import pandas as pd


fig = px.line(zimmobdf4, x='Date', y='%Mobility Change', color = 'City', range_x=['2020-02-15','2020-05-29'], title='Mobility Trends',)

fig.show()
# Out:
# <div>
#
#
#             <div id="c21184c7-bcd6-445f-8234-8f581b842169" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c21184c7-bcd6-445f-8234-8f581b842169")) {
#                     Plotly.newPlot(
#                         'c21184c7-bcd6-445f-8234-8f581b842169',
# ...

# %%
fig = go.Figure(data=go.Heatmap(
        z=zimmobdf4['%Staying Put'],
        x=zimmobdf4['Date'],
        y=zimmobdf4['City'],       
        colorscale='plasma',
        colorbar=dict(thickness=20,lenmode='fraction',len=0.8,
                      tickcolor='black',tickfont=dict(size=10),y=0.8,
                     title='Proportion Staying at Home')
))

fig.update_layout(
    #title='Heat Map, Mobility in Zimbabwe, '+min_date+' to '+max_date, 
    titlefont=dict(size=14),
    yaxis_nticks=len(zimmobdf4['City'].unique()),
    xaxis_nticks=len(zimmobdf4['Date'].unique()),
    width=1200,
    height=700,
    yaxis=dict(title_text="Location", titlefont=dict(size=12),tickfont=dict(size=9)),
    xaxis=dict(title_text="Report Date",titlefont=dict(size=12),tickfont=dict(size=9)),
    margin=dict(l=50, r=50, b=100, t=100,pad=4)
)

fig.show()
# Out:
# <div>
#
#
#             <div id="cbc6f1cf-29f4-42c8-9b57-ba463f20a240" class="plotly-graph-div" style="height:700px; width:1200px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cbc6f1cf-29f4-42c8-9b57-ba463f20a240")) {
#                     Plotly.newPlot(
#                         'cbc6f1cf-29f4-42c8-9b57-ba463f20a240',
# ...

# %%
fig = go.Figure(data=go.Heatmap(
        z=zimmobdf4['%Mobility Change'],
        x=zimmobdf4['Date'],
        y=zimmobdf4['City'],       
        colorscale='plasma',
        colorbar=dict(thickness=20,lenmode='fraction',len=0.8,
                      tickcolor='black',tickfont=dict(size=10),y=0.8,
                     title='Proportion of Mobility Change')
))

fig.update_layout(
    #title='Heat Map, Mobility in Zimbabwe, '+min_date+' to '+max_date, 
    titlefont=dict(size=14),
    yaxis_nticks=len(zimmobdf4['City'].unique()),
    xaxis_nticks=len(zimmobdf4['Date'].unique()),
    width=1200,
    height=700,
    yaxis=dict(title_text="Location", titlefont=dict(size=12),tickfont=dict(size=9)),
    xaxis=dict(title_text="Report Date",titlefont=dict(size=12),tickfont=dict(size=9)),
    margin=dict(l=50, r=50, b=100, t=100,pad=4)
)

fig.show()
# Out:
# <div>
#
#
#             <div id="b5247757-b7f2-4dce-b857-2fe933ff49a2" class="plotly-graph-div" style="height:700px; width:1200px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b5247757-b7f2-4dce-b857-2fe933ff49a2")) {
#                     Plotly.newPlot(
#                         'b5247757-b7f2-4dce-b857-2fe933ff49a2',
# ...
